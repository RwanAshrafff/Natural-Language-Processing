# %% [markdown]
# # Taks 02
#
# Given the following text, perform the following:

# %%
text = '''
Ramadan is the ninth month of the Islamic lunar calendar and is considered one of the holiest months for Muslims around the world. During this month, Muslims fast from dawn until sunset as an act of worship, self-discipline, and spiritual reflection. Fasting includes refraining from food, drink, and other physical needs during daylight hours.
It comes this year on 19/02/2026 in Egypt but 18/02/2026 in KSA.
'''

text
# Out:
# '\nRamadan is the ninth month of the Islamic lunar calendar and is considered one of the holiest months for Muslims around the world. During this month, Muslims fast from dawn until sunset as an act of worship, self-discipline, and spiritual reflection. Fasting includes refraining from food, drink, and other physical needs during daylight hours.\nIt comes this year on 19/02/2026 in Egypt but 18/02/2026 in KSA.\n'

# %%
pip install nltk
# Out:
# ...
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# ...
# Using cached nltk-3.9.2-py3-none-any.whl (1.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Q1: Perform sentence tokenization and print the output.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
import string # to remove punctuations

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

print(f'Before sentence tokenization: {text} =============================================')
print(f'Text length before sentence tokenization {len(text)}')
print()

tokenized_sentences = sent_tokenize(text)
print(f'After sentence tokenization: {tokenized_sentences} =============================================')
print(f'Text length after sentence tokenization {len(tokenized_sentences)}')
# Out:
# Before sentence tokenization:
# Ramadan is the ninth month of the Islamic lunar calendar and is considered one of the holiest months for Muslims around the world. During this month, Muslims fast from dawn until sunset as an act of worship, self-discipline, and spiritual reflection. Fasting includes refraining from food, drink, and other physical needs during daylight hours.
# It comes this year on 19/02/2026 in Egypt but 18/02/2026 in KSA.
# ...
# Text length before sentence tokenization 411
#
# After sentence tokenization: ['\nRamadan is the ninth month of the Islamic lunar calendar and is considered one of the holiest months for Muslims around the world.', 'During this month, Muslims fast from dawn until sunset as an act of worship, self-discipline, and spiritual reflection.', 'Fasting includes refraining from food, drink, and other physical needs during daylight hours.', 'It comes this year on 19/02/2026 in Egypt but 18/02/2026 in KSA.'] =============================================
# ...

# %% [markdown]
# # Q2: Perform word tokenization and print the output.

# %%
print(f'Before work tokization: {text} =============================================')
print(f'Text length before work tokization {len(text)}')
print()

tokenized_words = word_tokenize(text)
print(f'After work tokization: {tokenized_words} =============================================')
print(f'Text length after work tokization {len(tokenized_words)}')
# Out:
# Before work tokization:
# Ramadan is the ninth month of the Islamic lunar calendar and is considered one of the holiest months for Muslims around the world. During this month, Muslims fast from dawn until sunset as an act of worship, self-discipline, and spiritual reflection. Fasting includes refraining from food, drink, and other physical needs during daylight hours.
# It comes this year on 19/02/2026 in Egypt but 18/02/2026 in KSA.
# ...
# Text length before work tokization 411
#
# ...

# %% [markdown]
# # Q3: Remove stop words and print the output.

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

nltk.download('stopwords')

stopwords = set(stopwords.words('english'))

print(f"Stopwords in English: {stopwords} \n")
# Out:
# Stopwords in English: {"couldn't", "you've", 'having', "hadn't", "should've", 'wouldn', 'd', 'm', 'into', 'my', 'hers', 'whom', 'here', 'them', 'no', 'and', 'off', 's', 'each', 'how', 'theirs', 'did', 'he', 'too', 'can', 'against', 'an', 'the', 'through', 'ma', 'over', 'under', 'didn', 'you', 'only', 'wasn', 'll', 'yourselves', 'very', 'do', 'both', 'which', 'during', 'needn', 'more', 'when', 'these', 'ours', 'weren', 'isn', 'o', 'then', "they'll", 'while', 'own', 'below', 're', 'after', 'been', 'don', 'won', 'does', 'doesn', 'is', 'were', 'myself', 'doing', 'some', 'yourself', "they've", 'before', "they're", "haven't", "needn't", 'same', "wouldn't", 'that', "hasn't", 'any', 'in', 'being', 'we', 'for', 'hasn', "shouldn't", 'am', 'themselves', "i've", 'nor', 'as', 'are', "we're", 'just', 'all', 'now', "we've", 'your', 'be', 'not', 'yours', 'will', 'it', "wasn't", 'have', 'such', "she's", 'further', "won't", 'had', 'itself', "i'll", 'other', 'ourselves', "don't", 'mustn', "mightn't", '
# ...

# %%
words = word_tokenize(text)
words_filtered = []

for w in words:
  if w not in stopwords:
    words_filtered.append(w)

print(50*"=")
print(f"Sentence before removing stopwords: {text}")
print(50*"=")
print(f"Sentence after removing stopwords: {words_filtered}")
print(50*"=")
# Out:
# ...
# Sentence before removing stopwords:
# Ramadan is the ninth month of the Islamic lunar calendar and is considered one of the holiest months for Muslims around the world. During this month, Muslims fast from dawn until sunset as an act of worship, self-discipline, and spiritual reflection. Fasting includes refraining from food, drink, and other physical needs during daylight hours.
# It comes this year on 19/02/2026 in Egypt but 18/02/2026 in KSA.
#
# ...
# Sentence after removing stopwords: ['Ramadan', 'ninth', 'month', 'Islamic', 'lunar', 'calendar', 'considered', 'one', 'holiest', 'months', 'Muslims', 'around', 'world', '.', 'During', 'month', ',', 'Muslims', 'fast', 'dawn', 'sunset', 'act', 'worship', ',', 'self-discipline', ',', 'spiritual', 'reflection', '.', 'Fasting', 'includes', 'refraining', 'food', ',', 'drink', ',', 'physical', 'needs', 'daylight', 'hours', '.', 'It', 'comes', 'year', '19/02/2026', 'Egypt', '18/02/2026', 'KSA', '.']
# ...

# %% [markdown]
# # Q4: Remove punctuations and print the output.

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# Punctuation removal
tokens = [token for token in tokenized_words if token not in string.punctuation] # if a token is not a punctuation, keep it.
tokens
# Out:
# ['Ramadan',
#  'is',
#  'the',
#  'ninth',
#  'month',
#  'of',
#  'the',
#  'Islamic',
#  'lunar',
#  'calendar',
#  'and',
#  'is',
#  'considered',
#  'one',
#  'of',
#  'the',
#  'holiest',
#  'months',
#  'for',
#  'Muslims',
#  'around',
#  'the',
#  'world',
#  'During',
#  'this',
#  'month',
#  'Muslims',
#  'fast',
#  'from',
#  'dawn',
#  'until',
#  'sunset',
#  'as',
#  'an',
#  'act',
#  'of',
#  'worship',
#  'self-discipline',
#  'and',
#  'spiritual',
#  'reflection',
#  'Fasting',
#  'includes',
#  'refraining',
#  'from',
#  'food',
#  'drink',
#  'and',
#  'other',
#  'physical',
#  'needs',
#  'during',
#  'daylight',
#  'hours',
#  'It',
#  'comes',
#  'this',
#  'year',
#  'on',
#  '19/02/2026',
#  'in',
#  'Egypt',
#  'but',
#  '18/02/2026',
#  'in',
#  'KSA']

# %% [markdown]
# # Q5: Perform  stemming and print the output.

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# Input text instead of list

# 1. Tokenize the text into words
tokens = word_tokenize(text)

# 2. Initialize the stemmer
ps = PorterStemmer()

# 3. Apply stemming
stemmed_tokens = [ps.stem(word) for word in tokens]

print("Original sentence:")
print(text)

# 4. Display results
print("\nOriginal Tokens:")
print(tokens)

print("\nStemmed Tokens:")
print(stemmed_tokens)
# Out:
# Original sentence:
#
# Ramadan is the ninth month of the Islamic lunar calendar and is considered one of the holiest months for Muslims around the world. During this month, Muslims fast from dawn until sunset as an act of worship, self-discipline, and spiritual reflection. Fasting includes refraining from food, drink, and other physical needs during daylight hours.
# It comes this year on 19/02/2026 in Egypt but 18/02/2026 in KSA.
#
#
# Original Tokens:
# ...

# %% [markdown]
# # Q6: Perform lemmatization and print the output.

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

#nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Tokenize the sentence
tokens = word_tokenize(text)

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

# Lemmatize each token
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]

# Print results
print("Original Tokens:")
print(tokens)

print("\nLemmatized Tokens:")
print(lemmatized_tokens)
# Out:
# Original Tokens:
# ['Ramadan', 'is', 'the', 'ninth', 'month', 'of', 'the', 'Islamic', 'lunar', 'calendar', 'and', 'is', 'considered', 'one', 'of', 'the', 'holiest', 'months', 'for', 'Muslims', 'around', 'the', 'world', '.', 'During', 'this', 'month', ',', 'Muslims', 'fast', 'from', 'dawn', 'until', 'sunset', 'as', 'an', 'act', 'of', 'worship', ',', 'self-discipline', ',', 'and', 'spiritual', 'reflection', '.', 'Fasting', 'includes', 'refraining', 'from', 'food', ',', 'drink', ',', 'and', 'other', 'physical', 'needs', 'during', 'daylight', 'hours', '.', 'It', 'comes', 'this', 'year', 'on', '19/02/2026', 'in', 'Egypt', 'but', '18/02/2026', 'in', 'KSA', '.']
#
# Lemmatized Tokens:
# ...

# %% [markdown]
# # Q7: Extract all digits using regex.

# %%
pip install regex
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import re
print(text)
pattern = r'\d' # one digit
matches = re.findall(pattern, text)
matches
# Out:
# Ramadan is the ninth month of the Islamic lunar calendar and is considered one of the holiest months for Muslims around the world. During this month, Muslims fast from dawn until sunset as an act of worship, self-discipline, and spiritual reflection. Fasting includes refraining from food, drink, and other physical needs during daylight hours.
# It comes this year on 19/02/2026 in Egypt but 18/02/2026 in KSA.
# ['1',
#  '9',
#  '0',
#  '2',
#  '2',
#  '0',
#  '2',
#  '6',
#  '1',
#  '8',
#  '0',
#  '2',
#  '2',
#  '0',
#  '2',
#  '6']

# %% [markdown]
# # Q8: Extract all characters with len 4.

# %%
print(text)
pattern = r'\w{4}' # 3 consective chars
matches = re.findall(pattern, text)
matches
# Out:
# Ramadan is the ninth month of the Islamic lunar calendar and is considered one of the holiest months for Muslims around the world. During this month, Muslims fast from dawn until sunset as an act of worship, self-discipline, and spiritual reflection. Fasting includes refraining from food, drink, and other physical needs during daylight hours.
# It comes this year on 19/02/2026 in Egypt but 18/02/2026 in KSA.
# ['Rama',
#  'nint',
#  'mont',
#  'Isla',
#  'luna',
#  'cale',
#  'ndar',
#  'cons',
#  'ider',
#  'holi',
#  'mont',
#  'Musl',
#  'arou',
#  'worl',
#  'Duri',
#  'this',
#  'mont',
#  'Musl',
#  'fast',
#  'from',
#  'dawn',
#  'unti',
#  'suns',
#  'wors',
#  'self',
#  'disc',
#  'ipli',
#  'spir',
#  'itua',
#  'refl',
#  'ecti',
#  'Fast',
#  'incl',
#  'udes',
#  'refr',
#  'aini',
#  'from',
#  'food',
#  'drin',
#  'othe',
#  'phys',
#  'ical',
#  'need',
#  'duri',
#  'dayl',
#  'ight',
#  'hour',
#  'come',
#  'this',
#  'year',
#  '2026',
#  'Egyp',
#  '2026']
